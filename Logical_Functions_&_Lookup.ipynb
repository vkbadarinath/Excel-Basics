# %% [markdown]
# 1) Write a formula to check if the marks in cell B2 are Greater than or eqal to 40. If yes , returns "Pass", other "Fail".
#
# A)  ![Screenshot 2026-02-20 001510.png](data:image/png;base64,...)
#
# 2)  company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not.
#
# A)  ![Screenshot 2026-02-20 002708.png](data:image/png;base64,...)
#
# 3) Write a nested IF formula:
#     If marks in B2 are >= 90 "A",>= 75, "B",>= 50, "C", otherwise "Fail".
#
#   A) ![Screenshot 2026-02-20 003618.png](data:image/png;base64,...)
#
# 4) nd the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# A) ![Screenshot 2026-02-20 004536.png](data:image/png;base64,...)
#
# 5)  company has set the following commission structure for its sales team:
#   If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate applicable.
#
#   A)   ![Screenshot 2026-02-23 230415.png](data:image/png;base64,...)
#
# 6) The HR department maintains the following leave records of employees:onus or not .
#     Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#     .If Leaves Taken > Allowed Leaves, display "Exceeded".
#     .Otherwise, display "OK".
#
#   A)  ![Screenshot 2026-02-23 231125.png](data:image/png;base64,...)
#
# 7) Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# A) ![Screenshot 2026-02-23 231748.png](data:image/png;base64,...)
#
#
# 8)  Use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
# A)  ![Screenshot 2026-02-23 232332.png](data:image/png;base64,...)
